# %%
def metalstore():                                                                                    # --- defining a function --- #
    cart= {}
    total= 0
    intro= ''                                                                
    while intro != 0:
        print('Welcome to David"s Precious Metals. This is the main menu')                           # --------- main menu --------#
        intro= int(input('Enter 1 to begin, 2 to view cart or 0 to exit '))
        if intro == 1:                                                                               # - Menu option 1 (shop) Begin - #
            print('We have 3 item categories: Gold , Silver, and Copper. Which of these would you like? ') 
            cg= int(input('1 for Gold, 2 for Silver, 3 for Copper '))                                #           sub-menu
            if cg == 1:                                                                              # ----- sub category 1 begin -----#
                print('We have 1oz Coins, 5oz Bars and 10oz Bars. Which of these would you like?')  
                item_select= int(input('Enter 1 for 1oz Coin, 2 for 5oz Bar, 3 for 10oz Bar '))      # sub category 1 item select
                quantity= int(input('Enter item quantity'))                                          # ---- enters quantity ---- #
                if item_select == 1:
                    cart['1oz Gold Coin'] = quantity
                    total += quantity * 2000
                if item_select == 2:
                    cart['5oz Gold Bar'] = quantity
                    total += quantity * 10000
                if item_select == 3:                                    
                    cart['10oz Gold Bar'] = quantity
                    total += quantity * 20000
            elif cg == 2:
                print('We have 1oz Coins, 5oz Bars and 10oz Bars. Which of these would you like?')           # sub category 2 begin                     
                item_select= int(input('Enter 1 for 1oz Coin, 2 for 5oz Bar, 3 for 10oz Bar '))             # sub category 2 item select
                quantity= int(input('Enter item quantity '))                                            # ------ enters quantity ------#
                if item_select == 1:
                    cart['1oz Silver Coin'] = quantity
                    total += quantity * 30
                if item_select == 2:
                    cart['5oz Silver Bar'] = quantity
                    total += quantity * 150
                if item_select == 3:
                    cart['10oz Silver Bar'] = quantity
                    total += quantity * 300
            elif cg == 3:
                print('We have 1oz Coins, 5oz Bars and 10oz Bars. Which of these would you like?')            #sub category 3
                item_select= int(input('Enter 1 for 1oz Coin, 2 for 5oz Bar, 3 for 10oz Bar '))               # sub category 3 item select
                quantity= int(input('Enter item quantity '))                                              #  - -- enters quantity ----  #
                if item_select == 1:
                    cart['1oz Copper Coin'] = quantity
                    total += quantity * 2
                if item_select == 2:
                    cart['5oz Copper Bar'] = quantity
                    total += quantity * 10
                if item_select == 3:
                    cart['10oz Copper Bar'] = quantity
                    total += quantity * 20
            else:
                print('invalid entry')                                                                  # ------sub category 3 end----- #
        elif intro == 2:
            print(cart, 'Your total comes to $', total)
            ask= int(input('What would you like to do? 1 to checkout or 2 to remove items'))
            if ask == 2:
                cart.clear()
                print('Your cart is now empty')
            else:
                print(cart, 'Your total comes to $', total)
                break
        else:
            print(cart, 'Your total comes to $', total)
            break

# %%
metalstore()
# Out:
# Welcome to David"s Precious Metals. This is the main menu
# Enter 1 to begin, 2 to view cart or 0 to exit 1
# We have 3 item categories: Gold , Silver, and Copper. Which of these would you like?
# 1 for Gold, 2 for Silver, 3 for Copper 1
# We have 1oz Coins, 5oz Bars and 10oz Bars. Which of these would you like?
# Enter 1 for 1oz Coin, 2 for 5oz Bar, 3 for 10oz Bar 1
# Enter item quantity1
# Welcome to David"s Precious Metals. This is the main menu
# Enter 1 to begin, 2 to view cart or 0 to exit 1
# We have 3 item categories: Gold , Silver, and Copper. Which of these would you like?
# 1 for Gold, 2 for Silver, 3 for Copper 2
# We have 1oz Coins, 5oz Bars and 10oz Bars. Which of these would you like?
# Enter 1 for 1oz Coin, 2 for 5oz Bar, 3 for 10oz Bar 2
# Enter item quantity 2
# Welcome to David"s Precious Metals. This is the main menu
# Enter 1 to begin, 2 to view cart or 0 to exit 1
# We have 3 item categories: Gold , Silver, and Copper. Which of these would you like?
# 1 for Gold, 2 for Silver, 3 for Copper 3
# We have 1oz Coins, 5oz Bars and 10oz Bars. Which of these would you like?
# Enter 1 for 1oz Coin, 2 for 5oz Bar, 3 for 10oz Bar 3
# Enter item quantity 3
# Welcome to David"s Precious Metals. This is the main menu
# Enter 1 to begin, 2 to view cart or 0 to exit 2
# {'1oz Gold Coin': 1, '5oz Silver Bar': 2, '10oz Copper Bar': 3} Your total comes to $ 2360
# What would you like to do? 1 to checkout or 2 to remove items2
# Your cart is now empty
# Welcome to David"s Precious Metals. This is the main menu
# Enter 1 to begin, 2 to view cart or 0 to exit 1
# We have 3 item categories: Gold , Silver, and Copper. Which of these would you like?
# 1 for Gold, 2 for Silver, 3 for Copper 3
# We have 1oz Coins, 5oz Bars and 10oz Bars. Which of these would you like?
# Enter 1 for 1oz Coin, 2 for 5oz Bar, 3 for 10oz Bar 3
# Enter item quantity 3
# Welcome to David"s Precious Metals. This is the main menu
# Enter 1 to begin, 2 to view cart or 0 to exit 0
